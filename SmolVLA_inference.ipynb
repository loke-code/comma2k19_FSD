# %%
# !pip install lerobot
# !pip install num2words
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 9.7 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=1d1776a862ceff39d89a95703ec8b5d0b7b73948a04b1486665fcce2bb597d23
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built docopt
# ...

# %%
# %run ./comma2k19_FSD/dataset_setup.ipynb
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py:205: UserWarning: The `local_dir_use_symlinks` argument is deprecated and ignored in `hf_hub_download`. Downloading to a local directory does not use symlinks anymore.
#   warnings.warn(
# Data directories configured at: /content/comma2k19_data
# ...
# File verified! Size: 8.13 GB
# Success! Data downloaded.
# Found 7333 files in Chunk. Starting extraction...
# Extracting Chunk: 100%|██████████| 7333/7333 [01:23<00:00, 87.71it/s]
# Extraction complete! Files located at: /content/comma2k19_data/extracted
# --- Processing Folder: b0c9d2329ad1606b_2018-08-06--10-04-53 ---
#   Segment 25: Steer [ -7.20,   4.80] | Speed [ 28.02,  28.85] | Data points [Speed = 4974, Steer = 4974]
#   Segment 26: Steer [ -6.70,   3.00] | Speed [ 28.16,  33.81] | Data points [Speed = 4973, Steer = 4973]
#   Segment 29: Steer [ -6.20,   4.70] | Speed [ 24.82,  27.51] | Data points [Speed = 4974, Steer = 4973]
# ...

# %%
# %run comma2k19_FSD/run_smolvla_inference.py --chunk-path ./comma2k19_data/extracted/Chunk_1 --use-temporal-state
# Out:
# Loading  HuggingFaceTB/SmolVLM2-500M-Video-Instruct weights ...
# Loading weights:   0%|          | 0/489 [00:00<?, ?it/s]
# Reducing the number of VLM layers to 16 ...
# Loaded policy: lerobot/smolvla_base
# Device: cuda
# Expected visual keys: ['observation.images.camera1', 'observation.images.camera2', 'observation.images.camera3']
# Expected state key: observation.state with dim=6
# Using dataset: Comma_CAN_Temporal
#
# Sample 0
#   input_state: [24.14515495300293, -1.43185555934906, 24.206953048706055, -1.600000023841858, 24.30776596069336, -2.299999952316284]
#   pred_action: [[-0.010250024497509003, 0.11406004428863525, 1.9583104848861694, -2.5631275177001953, 1.0683491230010986, 0.5203790664672852]]
#   gt_future: {'speed': 23.367090225219727, 'steer': 2.9000000953674316}
#
# Sample 1
#   input_state: [16.333045959472656, -3.4000000953674316, 16.35211944580078, -3.200000047683716, 16.379846572875977, -2.200000047683716]
# ...
